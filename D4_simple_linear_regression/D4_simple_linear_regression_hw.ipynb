# %% [markdown]
# 作業目標 : 希望學員了解直線方程式，並觀察斜率即截距對於圖形的影響。
#
# 作業題目 : 自己設計一條直線。(提示:填入自己設計的斜率即截距。)

# %%
def line(w0,w1):
    x=np.linspace(-10,10)
    y = w0 + w1*x
    plt.plot(x,y)
    plt.xlim(-10,10)
    plt.ylim(-20,20)
    # string formatting
    plt.title('y = %f + %f * x'%(w0,w1))
    plt.xlabel('x')
    plt.ylabel('y')
    return 'finish'

# %%
import numpy as np
import matplotlib.pyplot as plt

line(0.678,1.567)
# Out:
# 'finish'
